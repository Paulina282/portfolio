# %% [markdown]
# ## O Danych
#
# Zbiór danych zawiera informacje o trzech gatunkach irysów: Iris setosa, Iris versicolor, i Iris virginica.
#
# Dane obejmują pomiary czterech cech: długość i szerokość działki kielicha oraz długość i szerokość płatka.
#
# Każdy wiersz w zbiorze danych reprezentuje pojedynczy kwiat, a wartości pomiarów są podane w centymetrach.
#
# Zbiór składa się z 150 próbek, po 50 dla każdego gatunku, i jest szeroko stosowany jako podstawowy zbiór danych do
# testowania algorytmów klasyfikacji oraz w nauce o danych i uczeniu maszynowym.
#
# Kolumny:
# * **długość kielicha (sepal length)** - Długość kielicha w cm
# * **szerokość kielicha (sepal width)** - Szerokość kielicha w cm
# * **długość płatka (petal length)** - Długość płatka w cm
# * **szerokość płatka (petal width)** - Szerokość płatka w cm
# * **klasa (class)** - Klasa irysa (setosa, versicolor, virginica)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('25__iris.csv', sep=",")
df
# Out:
#      długość kielicha (sepal length)  szerokość kielicha (sepal width)  \
# 0                                5.1                               3.5
# 1                                4.9                               3.0
# 2                                4.7                               3.2
# 3                                4.6                               3.1
# 4                                5.0                               3.6
# ..                               ...                               ...
# 145                              6.7                               3.0
# 146                              6.3                               2.5
# 147                              6.5                               3.0
# 148                              6.2                               3.4
# 149                              5.9                               3.0
#
#      długość płatka (petal length)  szerokość płatka (petal width)  \
# ...

# %% [markdown]
# # EDA - DANE DOTYCZĄCE IRYSÓW

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   długość kielicha (sepal length)   150 non-null    float64
#  1   szerokość kielicha (sepal width)  150 non-null    float64
#  2   długość płatka (petal length)     150 non-null    float64
#  3   szerokość płatka (petal width)    150 non-null    float64
#  4   klasa (class)                     150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.sample(10)
# Out:
#      długość kielicha (sepal length)  szerokość kielicha (sepal width)  \
# 97                               6.2                               2.9
# 40                               5.0                               3.5
# 121                              5.6                               2.8
# 138                              6.0                               3.0
# 132                              6.4                               2.8
# 41                               4.5                               2.3
# 70                               5.9                               3.2
# 105                              7.6                               3.0
# 118                              7.7                               2.6
# 111                              6.4                               2.7
#
#      długość płatka (petal length)  szerokość płatka (petal width)  \
# 97                             4.3                             1.3
# ...

# %%
df.tail(12)
# Out:
#      długość kielicha (sepal length)  szerokość kielicha (sepal width)  \
# 138                              6.0                               3.0
# 139                              6.9                               3.1
# 140                              6.7                               3.1
# 141                              6.9                               3.1
# 142                              5.8                               2.7
# 143                              6.8                               3.2
# 144                              6.7                               3.3
# 145                              6.7                               3.0
# 146                              6.3                               2.5
# 147                              6.5                               3.0
# 148                              6.2                               3.4
# 149                              5.9                               3.0
#
# ...

# %%
df.columns
# Out:
# Index(['długość kielicha (sepal length)', 'szerokość kielicha (sepal width)',
#        'długość płatka (petal length)', 'szerokość płatka (petal width)',
#        'klasa (class)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# długość kielicha (sepal length)     0
# szerokość kielicha (sepal width)    0
# długość płatka (petal length)       0
# szerokość płatka (petal width)      0
# klasa (class)                       0
# dtype: int64

# %% [markdown]
# ## Jakie wartości unikatowe zawiera ten zestaw danych?

# %%
df.nunique()
# Out:
# długość kielicha (sepal length)     35
# szerokość kielicha (sepal width)    23
# długość płatka (petal length)       43
# szerokość płatka (petal width)      22
# klasa (class)                        3
# dtype: int64

# %% [markdown]
# #### Z powyższych danych można wnioskować, że kwiaty są najbardziej zróżnicowanej pod względem długości płatka.

# %%
df["klasa (class)"]
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: klasa (class), Length: 150, dtype: object

# %%
df.groupby('klasa (class)', as_index=False)['długość kielicha (sepal length)'].nunique()
# Out:
#      klasa (class)  długość kielicha (sepal length)
# 0      Iris-setosa                               15
# 1  Iris-versicolor                               21
# 2   Iris-virginica                               21

# %%
df.groupby('klasa (class)', as_index=False)['szerokość kielicha (sepal width)'].nunique()
# Out:
#      klasa (class)  szerokość kielicha (sepal width)
# 0      Iris-setosa                                16
# 1  Iris-versicolor                                14
# 2   Iris-virginica                                13

# %%
df.groupby('klasa (class)', as_index=False)['długość płatka (petal length)'].nunique()
# Out:
#      klasa (class)  długość płatka (petal length)
# 0      Iris-setosa                              9
# 1  Iris-versicolor                             19
# 2   Iris-virginica                             20

# %%
df.groupby('klasa (class)', as_index=False)['szerokość płatka (petal width)'].nunique()
# Out:
#      klasa (class)  szerokość płatka (petal width)
# 0      Iris-setosa                               6
# 1  Iris-versicolor                               9
# 2   Iris-virginica                              12

# %% [markdown]
# #### Z danych unikatowych w każdej klasie irysów wynika, że kwiaty w klasie Iris virginica są najbardziej zróżnicowane pod względem kształtu, najmniej zróżnicowane wartości posiadają zaś kwiaty z klasy Irys setosa.

# %% [markdown]
# ## Ile rodzajów klas irysów zawierają dane?

# %%
df["klasa (class)"].nunique()
# Out:
# 3

# %% [markdown]
# ## Ile danych zawiera każda z trzech klas?

# %%
df["klasa (class)"].value_counts().plot(kind='bar', color=['skyblue', 'violet', 'yellow'])
# Out:
# <Axes: >

# %% [markdown]
# ## Który z rodzajów irysów ma najbardziej okrągły kształt płatka?

# %%
df.corr(numeric_only=True)
# Out:
#                                   długość kielicha (sepal length)  \
# długość kielicha (sepal length)                          1.000000
# szerokość kielicha (sepal width)                        -0.109369
# długość płatka (petal length)                            0.871754
# szerokość płatka (petal width)                           0.817954
#
#                                   szerokość kielicha (sepal width)  \
# długość kielicha (sepal length)                          -0.109369
# szerokość kielicha (sepal width)                          1.000000
# długość płatka (petal length)                            -0.420516
# szerokość płatka (petal width)                           -0.356544
#
#                                   długość płatka (petal length)  \
# długość kielicha (sepal length)                        0.871754
# szerokość kielicha (sepal width)                      -0.420516
# długość płatka (petal length)                          1.000000
# ...

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(8, 6))
sns.heatmap(corr, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Matryca korelacji")
plt.show()

# %% [markdown]
# #### Szerokość płatka koreluje z długością płatką. Zobaczmy, jak ta korelacja wygląda w poszczególnych klasach irysów.

# %%
df.iloc[1:50].corr(numeric_only=True)
# Out:
#                                   długość kielicha (sepal length)  \
# długość kielicha (sepal length)                          1.000000
# szerokość kielicha (sepal width)                         0.746498
# długość płatka (petal length)                            0.266497
# szerokość płatka (petal width)                           0.282074
#
#                                   szerokość kielicha (sepal width)  \
# długość kielicha (sepal length)                           0.746498
# szerokość kielicha (sepal width)                          1.000000
# długość płatka (petal length)                             0.178687
# szerokość płatka (petal width)                            0.282444
#
#                                   długość płatka (petal length)  \
# długość kielicha (sepal length)                        0.266497
# szerokość kielicha (sepal width)                       0.178687
# długość płatka (petal length)                          1.000000
# ...

# %%
matryca_setosa = df.iloc[1:50].corr(numeric_only=True)
plt.figure(figsize=(8, 6))
sns.heatmap(matryca_setosa, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Matryca korelacji")
plt.show()

# %% [markdown]
# ### Korelacja długości płatka z szerokością płatka w klasie irys setosa wynosi ~ 0.3.

# %%
df.iloc[50:100].corr(numeric_only=True)
# Out:
#                                   długość kielicha (sepal length)  \
# długość kielicha (sepal length)                          1.000000
# szerokość kielicha (sepal width)                         0.525911
# długość płatka (petal length)                            0.754049
# szerokość płatka (petal width)                           0.546461
#
#                                   szerokość kielicha (sepal width)  \
# długość kielicha (sepal length)                           0.525911
# szerokość kielicha (sepal width)                          1.000000
# długość płatka (petal length)                             0.560522
# szerokość płatka (petal width)                            0.663999
#
#                                   długość płatka (petal length)  \
# długość kielicha (sepal length)                        0.754049
# szerokość kielicha (sepal width)                       0.560522
# długość płatka (petal length)                          1.000000
# ...

# %%
matryca_versicolor = df.iloc[50:100].corr(numeric_only=True)
plt.figure(figsize=(8, 6))
sns.heatmap(matryca_versicolor, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Matryca korelacji")
plt.show()

# %% [markdown]
# ### Korelacja między długością płatka a szerokością wpłatka w klasie irysów versicolor wynosi ~ 0.8.

# %%
df.iloc[100:150].corr(numeric_only=True)
# Out:
#                                   długość kielicha (sepal length)  \
# długość kielicha (sepal length)                          1.000000
# szerokość kielicha (sepal width)                         0.457228
# długość płatka (petal length)                            0.864225
# szerokość płatka (petal width)                           0.281108
#
#                                   szerokość kielicha (sepal width)  \
# długość kielicha (sepal length)                           0.457228
# szerokość kielicha (sepal width)                          1.000000
# długość płatka (petal length)                             0.401045
# szerokość płatka (petal width)                            0.537728
#
#                                   długość płatka (petal length)  \
# długość kielicha (sepal length)                        0.864225
# szerokość kielicha (sepal width)                       0.401045
# długość płatka (petal length)                          1.000000
# ...

# %%
matryca_virginica = df.iloc[100:150].corr(numeric_only=True)
plt.figure(figsize=(8, 6))
sns.heatmap(matryca_virginica, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Matryca korelacji")
plt.show()

# %% [markdown]
# ### Korelacja między długością płatka a szerokością płatka w klasie irysów virginica wynosi ~ 0.3.

# %% [markdown]
# #### Możemy wnioskować, że najokrąglejsze płatki będą miały kwiaty z klasy irysów versicolor.

# %% [markdown]
# ## Który rodzaj irysów ma największe kwiaty?

# %%
df.groupby('klasa (class)', as_index=False)['szerokość kielicha (sepal width)'].mean()
# Out:
#      klasa (class)  szerokość kielicha (sepal width)
# 0      Iris-setosa                             3.418
# 1  Iris-versicolor                             2.770
# 2   Iris-virginica                             2.974

# %%
df.groupby('klasa (class)', as_index=False)['długość kielicha (sepal length)'].mean()
# Out:
#      klasa (class)  długość kielicha (sepal length)
# 0      Iris-setosa                            5.006
# 1  Iris-versicolor                            5.936
# 2   Iris-virginica                            6.588

# %%
df.groupby('klasa (class)', as_index=False)['szerokość płatka (petal width)'].mean()
# Out:
#      klasa (class)  szerokość płatka (petal width)
# 0      Iris-setosa                           0.244
# 1  Iris-versicolor                           1.326
# 2   Iris-virginica                           2.026

# %%
df.groupby('klasa (class)', as_index=False)['długość płatka (petal length)'].mean()
# Out:
#      klasa (class)  długość płatka (petal length)
# 0      Iris-setosa                          1.464
# 1  Iris-versicolor                          4.260
# 2   Iris-virginica                          5.552

# %% [markdown]
# ### Iris virginica ma największe średnie wartości, a najmniejsze Irys setosa.

# %% [markdown]
# ## Jakie są maksymalne i minimalne wartości w każdej klasie irysów?

# %%
df.groupby('klasa (class)', as_index=False)['szerokość kielicha (sepal width)'].max()
# Out:
#      klasa (class)  szerokość kielicha (sepal width)
# 0      Iris-setosa                               4.4
# 1  Iris-versicolor                               3.4
# 2   Iris-virginica                               3.8

# %%
df.groupby('klasa (class)', as_index=False)['długość kielicha (sepal length)'].max()
# Out:
#      klasa (class)  długość kielicha (sepal length)
# 0      Iris-setosa                              5.8
# 1  Iris-versicolor                              7.0
# 2   Iris-virginica                              7.9

# %%
df.groupby('klasa (class)', as_index=False)['szerokość płatka (petal width)'].max()
# Out:
#      klasa (class)  szerokość płatka (petal width)
# 0      Iris-setosa                             0.6
# 1  Iris-versicolor                             1.8
# 2   Iris-virginica                             2.5

# %%
df.groupby('klasa (class)', as_index=False)['długość płatka (petal length)'].max()
# Out:
#      klasa (class)  długość płatka (petal length)
# 0      Iris-setosa                            1.9
# 1  Iris-versicolor                            5.1
# 2   Iris-virginica                            6.9

# %%
df.groupby('klasa (class)', as_index=False)['szerokość kielicha (sepal width)'].min()
# Out:
#      klasa (class)  szerokość kielicha (sepal width)
# 0      Iris-setosa                               2.3
# 1  Iris-versicolor                               2.0
# 2   Iris-virginica                               2.2

# %%
df.groupby('klasa (class)', as_index=False)['długość kielicha (sepal length)'].min()
# Out:
#      klasa (class)  długość kielicha (sepal length)
# 0      Iris-setosa                              4.3
# 1  Iris-versicolor                              4.9
# 2   Iris-virginica                              4.9

# %%
df.groupby('klasa (class)', as_index=False)['szerokość płatka (petal width)'].min()
# Out:
#      klasa (class)  szerokość płatka (petal width)
# 0      Iris-setosa                             0.1
# 1  Iris-versicolor                             1.0
# 2   Iris-virginica                             1.4

# %%
df.groupby('klasa (class)', as_index=False)['długość płatka (petal length)'].min()
# Out:
#      klasa (class)  długość płatka (petal length)
# 0      Iris-setosa                            1.0
# 1  Iris-versicolor                            3.0
# 2   Iris-virginica                            4.5

# %%
df_clean = df.dropna(subset=['klasa (class)', 'szerokość kielicha (sepal width)'])
plt.figure(figsize=(8, 6))
sns.countplot(data=df_clean, x='klasa (class)', hue='szerokość kielicha (sepal width)')
plt.title('Występowanie min i max szerokości kielicha w każdej klasie')
plt.xlabel('Klasa')
plt.ylabel('Liczba wystąpień')
plt.legend(title='Szerokość kielicha')
plot_filename = "szerokosc_klasa_max.png"
plt.savefig(plot_filename)

# %%
df_clean = df[df['szerokość kielicha (sepal width)'] > 3]
plt.figure(figsize=(8, 6))
sns.countplot(data=df_clean, x='klasa (class)', hue='szerokość kielicha (sepal width)')
plt.title('Szerokość kielicha > 3 w każdej klasie')
plt.xlabel('Klasa')
plt.ylabel('Liczba wystąpień')
plt.legend(title='Szerokość kielicha')
plot_filename = "szerokosc3_klasa_max.png"
plt.savefig(plot_filename)

# %%
df_clean = df.dropna(subset=['klasa (class)', 'długość kielicha (sepal length)'])
plt.figure(figsize=(8, 6))
sns.countplot(data=df_clean, x='klasa (class)', hue='długość kielicha (sepal length)')
plt.title('Występowanie min i max długości kielicha w każdej klasie')
plt.xlabel('Klasa')
plt.ylabel('Liczba wystąpień')
plt.legend(title='Długość kielicha')
plot_filename = "długość_klasa_max.png"
plt.savefig(plot_filename)

# %%
df_clean = df.dropna(subset=['klasa (class)', 'szerokość płatka (petal width)'])
plt.figure(figsize=(8, 6))
sns.countplot(data=df_clean, x='klasa (class)', hue='szerokość płatka (petal width)')
plt.title('Występowanie min i max szerokości płatka w każdej klasie')
plt.xlabel('Klasa')
plt.ylabel('Liczba wystąpień')
plt.legend(title='Szerokość płatka')
plot_filename = "szerokosc_platka_klasa_max.png"
plt.savefig(plot_filename)

# %%
df_clean = df.dropna(subset=['klasa (class)', 'długość płatka (petal length)'])
plt.figure(figsize=(8, 6))
sns.countplot(data=df_clean, x='klasa (class)', hue='długość płatka (petal length)')
plt.title('Występowanie min i max długości płatka w każdej klasie')
plt.xlabel('Klasa')
plt.ylabel('Liczba danych')
plt.legend(title='Długość płatka')
plot_filename = "długość_platka_klasa_max.png"
plt.savefig(plot_filename)

# %% [markdown]
# ### Zestawienie danych dla każdej klasy irysów wygeneruję w pairplocie.

# %%
sns.pairplot(df, hue='klasa (class)', palette="pastel")

# %%
sns.pairplot(df, kind="kde", hue='klasa (class)')

# %%
df.max()
# Out:
# długość kielicha (sepal length)                7.9
# szerokość kielicha (sepal width)               4.4
# długość płatka (petal length)                  6.9
# szerokość płatka (petal width)                 2.5
# klasa (class)                       Iris-virginica
# dtype: object

# %%
df.min()
# Out:
# długość kielicha (sepal length)             4.3
# szerokość kielicha (sepal width)            2.0
# długość płatka (petal length)               1.0
# szerokość płatka (petal width)              0.1
# klasa (class)                       Iris-setosa
# dtype: object

# %% [markdown]
# ## Możemy wnioskować, że najwieksze kwiaty to Irysy virginica, a najdrobniejsze - Irysy setosa.

# %% [markdown]
# ## Które klasy irysów najbardziej się wyróżniają?

# %%
df.groupby('klasa (class)', as_index=False)['szerokość płatka (petal width)'].std()
# Out:
#      klasa (class)  szerokość płatka (petal width)
# 0      Iris-setosa                        0.107210
# 1  Iris-versicolor                        0.197753
# 2   Iris-virginica                        0.274650

# %%
df.groupby('klasa (class)', as_index=False)['długość płatka (petal length)'].std()
# Out:
#      klasa (class)  długość płatka (petal length)
# 0      Iris-setosa                       0.173511
# 1  Iris-versicolor                       0.469911
# 2   Iris-virginica                       0.551895

# %%
df.groupby('klasa (class)', as_index=False)['długość kielicha (sepal length)'].std()
# Out:
#      klasa (class)  długość kielicha (sepal length)
# 0      Iris-setosa                         0.352490
# 1  Iris-versicolor                         0.516171
# 2   Iris-virginica                         0.635880

# %%
df.groupby('klasa (class)', as_index=False)['szerokość kielicha (sepal width)'].std()
# Out:
#      klasa (class)  szerokość kielicha (sepal width)
# 0      Iris-setosa                          0.381024
# 1  Iris-versicolor                          0.313798
# 2   Iris-virginica                          0.322497

# %% [markdown]
# #### Z tych danych również wynika, że Irys versicolor i Irys virginica będą kwiatami podobnymi do siebie pod względem wielkości i kształtu płatków i kielicha, podczas gdy Irysy setosa będą od nich mniejsze.

# %% [markdown]
# ## Wnioski

# %% [markdown]
# ### Irysy setosa to najłatwiej rozpoznawalne kwiaty irysów
# #### • pokazała to analiza na zbiorze danych obejmującym 150 kwiatów
# #### • z danych wyróżniono 3 klasy irysów: setosa, versicolor i virginica
# #### • płatki tej klasy irysów setosa są drobniejsze od pozostałych

# %% [markdown]
# ### Płatki irysów versicolor mają najokrąglejszy kształt
# #### • korelacja między długością płatka a szerokością płatka w klasie irysów virginica wynosi ~ 0.3

# %% [markdown]
# ### Kwiaty irysów versicolor i virginica najłatwiej ze sobą pomylić
# #### • te klasy irysów posiadają zbliżone wartości wielkości płatka i kielicha, jednak irysy virginica są nieznacznie większe

# %% [markdown]
# ### Rekomendacje
# #### • w celu urozmaicenia hodowli kwiatów z grupy irysów zaleca się kupić nasiona irysa versicolor i irysa setosa
# #### • w przypadku braku w hurtowni nasion irysów versicolor można zastąpić je porównywalnymi nasionami kwiatów virginica

# %% [markdown]
# #### Poniżej przykładowe fotografie każdego z klas irysów.
#
# - Irys setosa

# %% [markdown]
# ![Irys setosa](https://www.plant-world-seeds.com/images/item_images/000/007/023/large_square/iris_baby_blue.jpg?1500653527)

# %% [markdown]
# - Irys versicolor

# %% [markdown]
# ![Irys versicolor](https://upload.wikimedia.org/wikipedia/commons/2/27/Blue_Flag%2C_Ottawa.jpg)

# %% [markdown]
# - Irys virginica

# %% [markdown]
# ![Irys virginica](https://daylily-phlox.eu/wp-content/uploads/2021/09/Iris-virginica-%E2%80%98Sumpfprinzessin%E2%80%99-400x400.jpg)

# %%
# !jupyter nbconvert --to html "irysy_PJ_EDA.ipynb"
# Out:
# [NbConvertApp] Converting notebook irysy_PJ_EDA.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 12 image(s).
# [NbConvertApp] Writing 1835508 bytes to irysy_PJ_EDA.html
